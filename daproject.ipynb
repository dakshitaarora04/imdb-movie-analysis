# %%
import pandas as pd
IMDB_df=pd.read_csv('imdb.csv')
IMDB_df
# Out:
#                                         Name  Date Rate    Votes  \
# 0                             No Time to Die  2021  7.6  107,163
# 1                                 The Guilty  2021  6.3   64,375
# 2                  The Many Saints of Newark  2021  6.4   27,145
# 3                Venom: Let There Be Carnage  2021  6.4   30,443
# 4                                       Dune  2021  8.3   84,636
# ...                                      ...   ...  ...      ...
# 6173  The Human Centipede II (Full Sequence)  2011  3.8   37,492
# 6174                        Double Indemnity  1944  8.3  150,448
# 6175      Before the Devil Knows You're Dead  2007  7.3  100,668
# 6176                              Queen Bees  2021  6.0      887
# 6177                              Death Race  2008  6.3  203,578
#
#                             Genre  Duration  Type Certificate Episodes  \
# 0     Action, Adventure, Thriller     163.0  Film       PG-13        -
# ...

# %%
IMDB_df.shape
# Out:
# (6178, 14)

# %%
IMDB_df.columns
# Out:
# Index(['Name', 'Date', 'Rate', 'Votes', 'Genre', 'Duration', 'Type',
#        'Certificate', 'Episodes', 'Nudity', 'Violence', 'Profanity', 'Alcohol',
#        'Frightening'],
#       dtype='object')

# %%
IMDB_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6178 entries, 0 to 6177
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         6178 non-null   object
#  1   Date         6178 non-null   int64
#  2   Rate         6178 non-null   object
#  3   Votes        6178 non-null   object
#  4   Genre        6178 non-null   object
#  5   Duration     5877 non-null   float64
#  6   Type         6178 non-null   object
#  7   Certificate  5728 non-null   object
#  8   Episodes     6178 non-null   object
#  9   Nudity       4719 non-null   object
#  10  Violence     5504 non-null   object
#  11  Profanity    5520 non-null   object
#  12  Alcohol      5407 non-null   object
#  13  Frightening  5320 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 675.8+ KB

# %%
IMDB_df.describe(include='object')
# Out:
#              Name  Rate     Votes   Genre  Type Certificate Episodes Nudity  \
# count        6178  6178      6178    6178  6178        5728     6178   4719
# unique       4820    77      4802     377     2          22      284      4
# top     King Kong   7.3  No Votes  Comedy  Film           R        -   Mild
# freq            5   273       185     268  4446        1885     4446   2292
#
#         Violence Profanity Alcohol Frightening
# count       5504      5520    5407        5320
# unique         4         4       4           4
# top     Moderate      Mild    Mild    Moderate
# freq        1814      2077    3257        1969

# %%
IMDB_df.loc[:,'Name']=='King Kong'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6173    False
# 6174    False
# 6175    False
# 6176    False
# 6177    False
# Name: Name, Length: 6178, dtype: bool

# %%
IMDB_df.Name=='King Kong'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6173    False
# 6174    False
# 6175    False
# 6176    False
# 6177    False
# Name: Name, Length: 6178, dtype: bool

# %%
IMDB_df.Name
# Out:
# 0                               No Time to Die
# 1                                   The Guilty
# 2                    The Many Saints of Newark
# 3                  Venom: Let There Be Carnage
# 4                                         Dune
#                          ...
# 6173    The Human Centipede II (Full Sequence)
# 6174                          Double Indemnity
# 6175        Before the Devil Knows You're Dead
# 6176                                Queen Bees
# 6177                                Death Race
# Name: Name, Length: 6178, dtype: object

# %%
kingkong_data=IMDB_df.loc[IMDB_df.loc[:,'Name']=='King Kong']
kingkong_data
# Out:
#            Name  Date Rate    Votes                      Genre  Duration  \
# 2084  King Kong  2005  7.2  407,876   Action, Adventure, Drama     187.0
# 4207  King Kong  1976  5.9   31,536          Adventure, Horror     134.0
# 4951  King Kong  1933  7.9   82,705  Adventure, Horror, Sci-Fi     100.0
# 5357  King Kong  1976  5.9   31,536          Adventure, Horror     134.0
# 6101  King Kong  1933  7.9   82,705  Adventure, Horror, Sci-Fi     100.0
#
#       Type Certificate Episodes Nudity  Violence Profanity Alcohol Frightening
# 2084  Film       PG-13        -   Mild  Moderate      Mild    Mild    Moderate
# 4207  Film          PG        -   Mild  Moderate      Mild    Mild    Moderate
# 4951  Film      Passed        -   Mild  Moderate       NaN    Mild    Moderate
# 5357  Film          PG        -   Mild  Moderate      Mild    Mild    Moderate
# 6101  Film      Passed        -   Mild  Moderate       NaN    Mild    Moderate

# %%
kingkong_data=IMDB_df.loc[IMDB_df.loc[:,'Name']=='King Kong']
kingkong_data
# Out:
#            Name  Date Rate    Votes                      Genre  Duration  \
# 2084  King Kong  2005  7.2  407,876   Action, Adventure, Drama     187.0
# 4207  King Kong  1976  5.9   31,536          Adventure, Horror     134.0
# 4951  King Kong  1933  7.9   82,705  Adventure, Horror, Sci-Fi     100.0
# 5357  King Kong  1976  5.9   31,536          Adventure, Horror     134.0
# 6101  King Kong  1933  7.9   82,705  Adventure, Horror, Sci-Fi     100.0
#
#       Type Certificate Episodes Nudity  Violence Profanity Alcohol Frightening
# 2084  Film       PG-13        -   Mild  Moderate      Mild    Mild    Moderate
# 4207  Film          PG        -   Mild  Moderate      Mild    Mild    Moderate
# 4951  Film      Passed        -   Mild  Moderate       NaN    Mild    Moderate
# 5357  Film          PG        -   Mild  Moderate      Mild    Mild    Moderate
# 6101  Film      Passed        -   Mild  Moderate       NaN    Mild    Moderate

# %%
IMDB_df=IMDB_df.drop_duplicates()   #drop the rows where values of each attribute is same

# %%
kingkong_data=IMDB_df.loc[IMDB_df.loc[:,'Name']=='King Kong']
kingkong_data
# Out:
#            Name  Date Rate    Votes                      Genre  Duration  \
# 2084  King Kong  2005  7.2  407,876   Action, Adventure, Drama     187.0
# 4207  King Kong  1976  5.9   31,536          Adventure, Horror     134.0
# 4951  King Kong  1933  7.9   82,705  Adventure, Horror, Sci-Fi     100.0
#
#       Type Certificate Episodes Nudity  Violence Profanity Alcohol Frightening
# 2084  Film       PG-13        -   Mild  Moderate      Mild    Mild    Moderate
# 4207  Film          PG        -   Mild  Moderate      Mild    Mild    Moderate
# 4951  Film      Passed        -   Mild  Moderate       NaN    Mild    Moderate

# %%
IMDB_df.shape
# Out:
# (5028, 14)

# %%
IMDB_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5023    False
# 5024    False
# 5025    False
# 5026    False
# 5027    False
# Length: 5028, dtype: bool

# %%
#any():returns true if any value is true and all() method :returns true if a value is true for all values

# %%
IMDB_df.duplicated().any()
# Out:
# False

# %% [markdown]
# Now in our dataframe no duplicate row are available

# %%
IMDB_df.isna().sum()
# Out:
# Name              0
# Date              0
# Rate              0
# Votes             0
# Genre             0
# Duration        248
# Type              0
# Certificate     344
# Episodes          0
# Nudity         1182
# Violence        531
# Profanity       524
# Alcohol         614
# Frightening     670
# dtype: int64

# %%
#before dealing with missing values transform the values in correct format

# %%
IMDB_df.isna().any()
# Out:
# Name           False
# Date           False
# Rate           False
# Votes          False
# Genre          False
# Duration        True
# Type           False
# Certificate     True
# Episodes       False
# Nudity          True
# Violence        True
# Profanity       True
# Alcohol         True
# Frightening     True
# dtype: bool

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,IMDB_df.shape[0]):
    IMDB_df['Votes'][i]=IMDB_df['Votes'][i].replace(',','')
    
IMDB_df['Votes']
# Out:
# 0       107163
# 1        64375
# 2        27145
# 3        30443
# 4        84636
#          ...
# 5023     37492
# 5024    150448
# 5025    100668
# 5026       887
# 5027    203578
# Name: Votes, Length: 5028, dtype: object

# %%
IMDB_df['Rate']=pd.to_numeric(IMDB_df['Rate'],errors='coerce',downcast='integer')
IMDB_df['Votes']=pd.to_numeric(IMDB_df['Votes'],errors='coerce',downcast='integer')
IMDB_df['Duration']=pd.to_numeric(IMDB_df['Duration'],errors='coerce',downcast='integer')

# %%
IMDB_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5028 entries, 0 to 5027
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         5028 non-null   object
#  1   Date         5028 non-null   int64
#  2   Rate         4875 non-null   float64
#  3   Votes        4875 non-null   float64
#  4   Genre        5028 non-null   object
#  5   Duration     4780 non-null   float64
#  6   Type         5028 non-null   object
#  7   Certificate  4684 non-null   object
#  8   Episodes     5028 non-null   object
#  9   Nudity       3846 non-null   object
#  10  Violence     4497 non-null   object
#  11  Profanity    4504 non-null   object
#  12  Alcohol      4414 non-null   object
#  13  Frightening  4358 non-null   object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 718.3+ KB

# %%
IMDB_df.isna().sum()
# Out:
# Name              0
# Date              0
# Rate            153
# Votes           153
# Genre             0
# Duration        248
# Type              0
# Certificate     344
# Episodes          0
# Nudity         1182
# Violence        531
# Profanity       524
# Alcohol         614
# Frightening     670
# dtype: int64

# %%
import numpy as np
IMDB_df['Rate']=IMDB_df['Rate'].replace(np.nan,0)
IMDB_df['Votes']=IMDB_df['Votes'].replace(np.nan,0)
IMDB_df['Duration']=IMDB_df['Duration'].replace(np.nan,0)

# %%
IMDB_df.isna().sum()
# Out:
# Name              0
# Date              0
# Rate              0
# Votes             0
# Genre             0
# Duration          0
# Type              0
# Certificate     344
# Episodes          0
# Nudity         1182
# Violence        531
# Profanity       524
# Alcohol         614
# Frightening     670
# dtype: int64

# %%
IMDB_df.Certificate.unique()
# Out:
# array(['PG-13', 'R', 'TV-MA', nan, 'TV-14', 'TV-PG', 'PG', 'TV-G',
#        '(Banned)', 'Not Rated', 'E', 'NC-17', 'TV-Y7-FV', 'TV-Y7',
#        'Unrated', 'Approved', 'G', 'TV-Y', 'GP', 'Passed', 'M', 'X',
#        'M/PG'], dtype=object)

# %%
IMDB_df.loc[IMDB_df.Certificate.isna()]
# Out:
#                          Name  Date  Rate   Votes                      Genre  \
# 7         House of the Dragon  2021   0.0     0.0   Action, Adventure, Drama
# 32                       Wolf  2021   4.1   229.0   Drama, Mystery, Thriller
# 81                   V/H/S/94  2021   5.5  3196.0  Horror, Mystery, Thriller
# 88                Ridley Road  2021   6.6   704.0                   Thriller
# 90    Spider-Man: No Way Home  2021   0.0     0.0  Action, Adventure, Sci-Fi
# ...                       ...   ...   ...     ...                        ...
# 4960            SAS Australia  1959   7.5   141.0                 Reality-TV
# 4974     A House on the Bayou  2021   0.0     0.0           Horror, Thriller
# 4986            Night Raiders  2021   6.4   118.0                     Sci-Fi
# 4991             The Forgiven  2021   6.8    62.0                      Drama
# 5008              My Struggle  2021   8.7    74.0                  Biography
#
# ...

# %% [markdown]
# Year wise movies and web series count

# %%
x=IMDB_df['Date'].unique()
np.sort(x)
# Out:
# array([1922, 1927, 1931, 1932, 1933, 1935, 1937, 1939, 1940, 1941, 1942,
#        1943, 1944, 1945, 1946, 1948, 1949, 1950, 1951, 1952, 1953, 1954,
#        1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965,
#        1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976,
#        1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#        2021, 2022, 2023], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(5,50))
sns.countplot(y='Date',data=IMDB_df,orient='h',stat='percent')
# Out:
# <Axes: xlabel='percent', ylabel='Date'>

# %%
higgh=IMDB_df.loc[IMDB_df.loc[:,'Rate']>9.6]
higgh
# Out:
#            Name  Date  Rate     Votes  Genre  Duration    Type Certificate  \
# 1946  Aspirants  2004   9.7  286206.0  Drama      45.0  Series         NaN
#
#      Episodes   Nudity Violence Profanity  Alcohol Frightening
# 1946        5  No Rate  No Rate   No Rate  No Rate     No Rate

# %% [markdown]
# #frequency highest for rating
# #countplot create in which x axis rate values 0 2 4 6 8 10 and plot the rate
# #which movie have highest vote and which movie lowest vote dont count 0
# #which field have maximum duration and which series have maximum duration
# #find all movie which is in a category Action  (string use in operator)
# #movie ie thriller drama and action and visualize it
# #compare the categories using count plot

# %%
fig=plt.figure(figsize=(5,50))
sns.countplot(y='Date',data=IMDB_df,orient='h',stat='percent')
